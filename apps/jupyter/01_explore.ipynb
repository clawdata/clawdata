# %% [markdown]
# # 01 Explore the ClawData Warehouse
#
# Connect to DuckDB and browse available tables.

# %%
from helpers import connect, query_df, list_tables, sample

con = connect()
print('Connected to DuckDB')

# %% [markdown]
# ## List Tables

# %%
list_tables(con)

# %% [markdown]
# ## Sample Data

# %%
sample(con, 'dim_customers', n=10)

# %% [markdown]
# ## Ad-hoc SQL

# %%
query_df(con, 'SELECT COUNT(*) AS total_orders, SUM(amount) AS total_revenue FROM fct_orders')
